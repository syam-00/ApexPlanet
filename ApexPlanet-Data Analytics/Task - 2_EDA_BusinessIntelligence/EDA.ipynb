# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the cleaned dataset
df = pd.read_csv("cleaned_sales.csv")

# %%
#Basic Dataset Understanding
df.shape
# Out:
# (9981, 22)

# %%
#Checking for missing values
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Total Sales'],
#       dtype='str')

# %%
#Statistical Summary
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9981.000000   9981.000000   9981.000000  9981.000000  9981.000000
# mean   5003.982667  55175.787496    229.547684     3.789400     0.155965
# std    2881.440861  32062.888932    622.751163     2.225407     0.206275
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2509.000000  23223.000000     17.300000     2.000000     0.000000
# 50%    5004.000000  56301.000000     54.528000     3.000000     0.200000
# 75%    7499.000000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit    Total Sales
# count  9981.000000    9981.000000
# mean     28.854530    1146.796960
# std     233.791364    3893.022194
# min   -6599.978000       0.444000
# 25%       1.732500      48.712000
# 50%       8.671500     183.750000
# 75%      29.364000     763.250000
# ...

# %%
#Sales Distribution Histogram
plt.figure(figsize=(8,5))
plt.hist(df['Sales'], bins=20)
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.title("Sales Distribution")
plt.show()

# %%
#Category Count Bar Chart
df['Category'].value_counts().plot(kind='bar')
plt.title("Product Categories")
plt.show()

# %%
#Heatmap Correlation
numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
#Scatter Plot
plt.scatter(df['Sales'], df['Profit'])
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.show()

# %% [markdown]
# Insights Writing
#
# observations like:
#
# 1. Technology category generated highest sales.
# 2. Western region contributed maximum revenue.
# 3. Higher discounts reduced profits.
# 4. Sales and profit show positive correlation.
